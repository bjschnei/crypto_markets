# %%
import provider
import datetime

# %%
bmdp = provider.BitmexDataProvider(datetime.datetime.now() - datetime.timedelta(days=2),
      datetime.datetime.now())
df = await bmdp._ConvertFilesToDataFrames().asend(None)
await bmdp.Close()

# %%
import datetime
import pandas as pd
# compute by the minute Open/High/Low/Close/Volume 
#df[df['symbol'] == 'XBTUSD']
df['timestamp'] = pd.to_datetime(df['timestamp'], format='%Y-%m-%dD%H:%M:%S.%f')
df['date'] = df['timestamp'].map(lambda x:x.date())
df['hour'] = df['timestamp'].map(lambda x:x.hour)
df['minute'] = df['timestamp'].map(lambda x:x.minute)
df['second'] = df['timestamp'].map(lambda x:x.second)

# %%
df[df['symbol'] == 'XBTUSD']
# Out:
#                         timestamp  symbol  side   size   price  tickDirection  \
# 168308 2019-07-27 00:00:02.914149  XBTUSD   Buy      3  9846.0       PlusTick
# 168309 2019-07-27 00:00:02.925757  XBTUSD   Buy      2  9846.0   ZeroPlusTick
# 168310 2019-07-27 00:00:02.936544  XBTUSD   Buy    430  9846.0   ZeroPlusTick
# 168311 2019-07-27 00:00:03.033507  XBTUSD  Sell    782  9845.5      MinusTick
# 168312 2019-07-27 00:00:03.207992  XBTUSD  Sell     50  9845.5  ZeroMinusTick
# 168313 2019-07-27 00:00:03.300420  XBTUSD   Buy  10500  9846.0       PlusTick
# 168314 2019-07-27 00:00:03.735584  XBTUSD  Sell   1300  9845.5      MinusTick
# 168315 2019-07-27 00:00:03.759209  XBTUSD  Sell   1150  9845.5  ZeroMinusTick
# 168316 2019-07-27 00:00:06.024359  XBTUSD  Sell   1000  9845.5  ZeroMinusTick
# 168317 2019-07-27 00:00:06.330256  XBTUSD   Buy    114  9846.0       PlusTick
# 168318 2019-07-27 00:00:06.878204  XBTUSD   Buy   3750  9846.0   ZeroPlusTick
# 168319 2019-07-27 00:00:07.212950  XBTUSD  Sell    850  9845.5      MinusTick
# 168320 2019-07-27 00:00:07.629121  XBTUSD  Sell   1200  9845.5  ZeroMinusTick
# 168321 2019-07-27 00:00:07.734846  XBTUSD  Sell   1000  9845.5  ZeroMinusTick
# 168322 2019-07-27 00:00:07.813421  XBTUSD   Buy    650  9846.0       PlusTick
# 168323 2019-07-27 00:00:07.842301  XBTUSD  Sell  19647  9845.5      MinusTick
# 168324 2019-07-27 00:00:07.930127  XBTUSD   Buy   7266  9846.0       PlusTick
# 168325 2019-07-27 00:00:07.991001  XBTUSD  Sell   1000  9845.5      MinusTick
# 168326 2019-07-27 00:00:08.103138  XBTUSD  Sell   1100  9845.5  ZeroMinusTick
# 168327 2019-07-27 00:00:08.159687  XBTUSD   Buy   6989  9846.0       PlusTick
# 168328 2019-07-27 00:00:08.159687  XBTUSD   Buy    511  9846.0   ZeroPlusTick
# 168329 2019-07-27 00:00:08.940735  XBTUSD  Sell   5000  9845.5      MinusTick
# 168330 2019-07-27 00:00:09.692079  XBTUSD   Buy    606  9846.0       PlusTick
# 168315           1150.0  2019-07-27     0       0       3
# 168316           1000.0  2019-07-27     0       0       6
# 168317            114.0  2019-07-27     0       0       6
# 168318           3750.0  2019-07-27     0       0       6
# 168319            850.0  2019-07-27     0       0       7
# 168320           1200.0  2019-07-27     0       0       7
# 168321           1000.0  2019-07-27     0       0       7
# 168322            650.0  2019-07-27     0       0       7
# 168323          19647.0  2019-07-27     0       0       7
# 168324           7266.0  2019-07-27     0       0       7
# 168325           1000.0  2019-07-27     0       0       7
# 168326           1100.0  2019-07-27     0       0       8
# 168327           6989.0  2019-07-27     0       0       8
# 168328            511.0  2019-07-27     0       0       8
# 168329           5000.0  2019-07-27     0       0       8
# 168330            606.0  2019-07-27     0       0       9
# 168331            120.0  2019-07-27     0       0      10
# 168332            120.0  2019-07-27     0       0      10
# 168333            120.0  2019-07-27     0       0      10
# 168334           4000.0  2019-07-27     0       0      10
# 168335           3523.0  2019-07-27     0       0      10
# 168336           3700.0  2019-07-27     0       0      10
# 168337            790.0  2019-07-27     0       0      10
# ...                 ...         ...   ...     ...     ...
# 887142           1000.0  2019-07-27    23      59      57
# 887143             30.0  2019-07-27    23      59      57
# 887144             35.0  2019-07-27    23      59      57
# 887145            123.0  2019-07-27    23      59      57
# 887146              4.0  2019-07-27    23      59      57
# 887147             30.0  2019-07-27    23      59      57
# 887148             28.0  2019-07-27    23      59      57
# 887149            250.0  2019-07-27    23      59      57
# 887150             66.0  2019-07-27    23      59      57
# 887151            200.0  2019-07-27    23      59      57
# 887152           1742.0  2019-07-27    23      59      57
# 887153             30.0  2019-07-27    23      59      57
# 887154            211.0  2019-07-27    23      59      57
# 887155           1500.0  2019-07-27    23      59      57
# 887156            533.0  2019-07-27    23      59      57
# 887157            135.0  2019-07-27    23      59      57
# 887158           6600.0  2019-07-27    23      59      57
# 887159          30000.0  2019-07-27    23      59      57
# 887160          74539.0  2019-07-27    23      59      57
# 887161           1400.0  2019-07-27    23      59      57
# 887162           1000.0  2019-07-27    23      59      57
# 887163          15000.0  2019-07-27    23      59      57
# 887164          20000.0  2019-07-27    23      59      57
# 887165          10000.0  2019-07-27    23      59      57
# 887166           6000.0  2019-07-27    23      59      57
# 887167           1000.0  2019-07-27    23      59      57
# 887168           2823.0  2019-07-27    23      59      57
# 887169          10000.0  2019-07-27    23      59      57
# 887170          10938.0  2019-07-27    23      59      57
# 887171            104.0  2019-07-27    23      59      59
#
# [718864 rows x 14 columns]

# %%
xbtusd_df = df[df['symbol'] == 'XBTUSD']
group = xbtusd_df.groupby(['symbol','date', 'hour', 'minute'])

# %%
# open/high/low/close/volume
ohlcv = group.agg({'price': ['first', 'max', 'min', 'last',], 'size': 'sum'})
ohlcv
# Out:
#                                  price                                 size
#                                  first      max      min     last       sum
# symbol date       hour minute
# XBTUSD 2019-07-27 0    0        9846.0   9846.0   9845.5   9846.0   1184416
#                        1        9845.5   9845.5   9830.0   9830.0   2577091
#                        53       9427.5   9430.0   9427.0   9430.0    129573
#                        54       9430.0   9436.0   9429.5   9436.0  14517838
#                        55       9435.5   9555.0   9435.5   9509.5  30403389
#                        56       9509.5   9527.0   9424.0   9444.5  11959115
#                        57       9445.0   9484.0   9435.5   9454.5   5484270
#                        58       9454.0   9470.0   9453.0   9469.5   2251941
#                        59       9469.5   9470.0   9460.0   9463.5   2053056
#
# [1440 rows x 5 columns]

# %%
# spot check agg works correctly for minute OCHLV data
l = xbtusd_df[(xbtusd_df['hour'] == 0) & (xbtusd_df['minute'] == 0)]['price'].min()
h = xbtusd_df[(xbtusd_df['hour'] == 0) & (xbtusd_df['minute'] == 0)]['price'].max()
o = xbtusd_df[(xbtusd_df['hour'] == 0) & (xbtusd_df['minute'] == 0)]['price'].iloc[0]
c = xbtusd_df[(xbtusd_df['hour'] == 0) & (xbtusd_df['minute'] == 0)]['price'].iloc[-1]
v = xbtusd_df[(xbtusd_df['hour'] == 0) & (xbtusd_df['minute'] == 0)]['size'].sum()

(o, c, h, l, v)
# Out:
# (9846.0, 9846.0, 9846.0, 9845.5, 1184416)

# %%
#ohlcv[['price', 'size']]
import datetime
ohlcv.loc[('XBTUSD', datetime.datetime.now().date() - datetime.timedelta(days=1), 0, 0)]
# Out:
# price  first       9846.0
#        max         9846.0
#        min         9845.5
#        last        9846.0
# size   sum      1184416.0
# Name: (XBTUSD, 2019-07-27, 0, 0), dtype: float64

# %%
all_group = df.groupby(['symbol','date', 'hour', 'minute'])
all_ohlcv = all_group.agg({'price': ['first', 'max', 'min', 'last',], 'size': 'sum'})

# %%
dir(all_ohlcv.index)
# Out:
# ['T',
#  '_MultiIndex__bounds',
#  '_MultiIndex__set_labels',
#  '_MultiIndex__set_levels',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getslice__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__init__',
#  '__init_subclass__',
#  '__inv__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmul__',
#  '__rpow__',
#  '__rtruediv__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__unicode__',
#  '__weakref__',
#  '__xor__',
#  '_accessors',
#  '_add_comparison_methods',
#  '_add_logical_methods',
#  '_add_logical_methods_disabled',
#  '_add_numeric_methods',
#  '_add_numeric_methods_add_sub_disabled',
#  '_add_numeric_methods_binary',
#  '_add_numeric_methods_disabled',
#  '_add_numeric_methods_unary',
#  '_allow_datetime_index_ops',
#  '_allow_index_ops',
#  '_allow_period_index_ops',
#  '_arrmap',
#  '_assert_can_do_op',
#  '_assert_can_do_setop',
#  '_assert_take_fillable',
#  '_attributes',
#  '_bounds',
#  '_box_scalars',
#  '_can_hold_na',
#  '_can_reindex',
#  '_cleanup',
#  '_coerce_scalar_to_index',
#  '_coerce_to_ndarray',
#  '_comparables',
#  '_concat',
#  '_concat_same_dtype',
#  '_constructor',
#  '_convert_arr_indexer',
#  '_convert_can_do_setop',
#  '_convert_for_op',
#  '_convert_index_indexer',
#  '_convert_list_indexer',
#  '_convert_listlike_indexer',
#  '_convert_scalar_indexer',
#  '_convert_slice_indexer',
#  '_convert_tolerance',
#  '_data',
#  '_deepcopy_if_needed',
#  '_defer_to_indexing',
#  '_deprecations',
#  '_dir_additions',
#  '_dir_deletions',
#  '_drop_from_level',
#  '_engine',
#  '_engine_type',
#  '_evaluate_compare',
#  '_evaluate_with_datetime_like',
#  '_evaluate_with_timedelta_like',
#  '_filter_indexer_tolerance',
#  '_format_attrs',
#  '_format_data',
#  '_format_native_types',
#  '_format_space',
#  '_format_with_header',
#  '_formatter_func',
#  '_from_elements',
#  '_get_attributes_dict',
#  '_get_consensus_name',
#  '_get_duplicates',
#  '_get_fill_indexer',
#  '_get_fill_indexer_searchsorted',
#  '_get_grouper_for_level',
#  '_get_labels',
#  '_get_labels_for_sorting',
#  '_get_level_indexer',
#  '_get_level_number',
#  '_get_level_values',
#  '_get_levels',
#  '_get_loc_only_exact_matches',
#  '_get_names',
#  '_get_nearest_indexer',
#  '_get_string_slice',
#  '_get_unique_index',
#  '_has_complex_internals',
#  '_hashed_indexing_key',
#  '_hashed_values',
#  '_have_mixed_levels',
#  '_id',
#  '_infer_as_myclass',
#  '_inferred_type_levels',
#  '_inner_indexer',
#  '_invalid_indexer',
#  '_is_memory_usage_qualified',
#  '_is_numeric_dtype',
#  '_is_strictly_monotonic_decreasing',
#  '_is_strictly_monotonic_increasing',
#  '_is_v1',
#  '_is_v2',
#  '_isnan',
#  '_join_level',
#  '_join_monotonic',
#  '_join_multi',
#  '_join_non_unique',
#  '_join_precedence',
#  '_labels',
#  '_left_indexer',
#  '_left_indexer_unique',
#  '_levels',
#  '_maybe_cast_indexer',
#  '_maybe_cast_slice_bound',
#  '_maybe_promote',
#  '_maybe_update_attributes',
#  '_mpl_repr',
#  '_na_value',
#  '_names',
#  '_nan_idxs',
#  '_nbytes',
#  '_outer_indexer',
#  '_partial_tup_index',
#  '_reduce',
#  '_reference_duplicate_name',
#  '_reindex_non_unique',
#  '_reset_cache',
#  '_reset_identity',
#  '_scalar_data_error',
#  '_searchsorted_monotonic',
#  '_set_labels',
#  '_set_levels',
#  '_set_names',
#  '_shallow_copy',
#  '_shallow_copy_with_infer',
#  '_simple_new',
#  '_sort_levels_monotonic',
#  '_string_data_error',
#  '_to_embed',
#  '_to_safe_for_reshape',
#  '_try_convert_to_int_index',
#  '_tuples',
#  '_typ',
#  '_unpickle_compat',
#  '_update_inplace',
#  '_validate_for_numeric_binop',
#  '_validate_for_numeric_unaryop',
#  '_validate_index_level',
#  '_validate_indexer',
#  '_validate_names',
#  '_values',
#  '_verify_integrity',
#  '_wrap_joined_index',
#  '_wrap_union_result',
#  'all',
#  'any',
#  'append',
#  'argmax',
#  'argmin',
#  'argsort',
#  'asi8',
#  'asof',
#  'asof_locs',
#  'astype',
#  'base',
#  'contains',
#  'copy',
#  'data',
#  'delete',
#  'difference',
#  'drop',
#  'drop_duplicates',
#  'droplevel',
#  'dropna',
#  'dtype',
#  'dtype_str',
#  'duplicated',
#  'empty',
#  'equal_levels',
#  'equals',
#  'factorize',
#  'fillna',
#  'flags',
#  'format',
#  'from_arrays',
#  'from_product',
#  'from_tuples',
#  'get_duplicates',
#  'get_indexer',
#  'get_indexer_for',
#  'get_indexer_non_unique',
#  'get_level_values',
#  'get_loc',
#  'get_loc_level',
#  'get_locs',
#  'get_major_bounds',
#  'get_slice_bound',
#  'get_value',
#  'get_values',
#  'groupby',
#  'has_duplicates',
#  'hasnans',
#  'holds_integer',
#  'identical',
#  'inferred_type',
#  'insert',
#  'intersection',
#  'is_',
#  'is_all_dates',
#  'is_boolean',
#  'is_categorical',
#  'is_floating',
#  'is_integer',
#  'is_interval',
#  'is_lexsorted',
#  'is_lexsorted_for_tuple',
#  'is_mixed',
#  'is_monotonic',
#  'is_monotonic_decreasing',
#  'is_monotonic_increasing',
#  'is_numeric',
#  'is_object',
#  'is_type_compatible',
#  'is_unique',
#  'isin',
#  'isna',
#  'isnull',
#  'item',
#  'itemsize',
#  'join',
#  'labels',
#  'levels',
#  'levshape',
#  'lexsort_depth',
#  'map',
#  'max',
#  'memory_usage',
#  'min',
#  'name',
#  'names',
#  'nbytes',
#  'ndim',
#  'nlevels',
#  'notna',
#  'notnull',
#  'nunique',
#  'putmask',
#  'ravel',
#  'reindex',
#  'remove_unused_levels',
#  'rename',
#  'reorder_levels',
#  'repeat',
#  'reshape',
#  'searchsorted',
#  'set_labels',
#  'set_levels',
#  'set_names',
#  'set_value',
#  'shape',
#  'shift',
#  'size',
#  'slice_indexer',
#  'slice_locs',
#  'sort',
#  'sort_values',
#  'sortlevel',
#  'strides',
#  'summary',
#  'swaplevel',
#  'symmetric_difference',
#  'take',
#  'to_datetime',
#  'to_frame',
#  'to_hierarchical',
#  'to_native_types',
#  'to_series',
#  'tolist',
#  'transpose',
#  'truncate',
#  'union',
#  'unique',
#  'value_counts',
#  'values',
#  'view',
#  'where']

# %%
set(all_ohlcv.index.get_level_values(level=0))
# Out:
# {'ADAU19',
#  'BCHU19',
#  'EOSU19',
#  'ETHU19',
#  'ETHUSD',
#  'LTCU19',
#  'TRXU19',
#  'XBT7D_D95',
#  'XBT7D_U105',
#  'XBTU19',
#  'XBTUSD',
#  'XBTZ19',
#  'XRPU19'}
